# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %% [markdown]
# # 서울시 교통사고 시각화

# %%
traffic_seoul = pd.read_csv("../Data/newSeoul_2005_2019.csv")
traffic_seoul.head()
# Out:
#      년도  월 자치구명  발생건수  사망자수  부상자수
# 0  2005  1  종로구    93     2   138
# 1  2005  2  종로구    84     3   125
# 2  2005  3  종로구   117     0   142
# 3  2005  4  종로구   138     2   212
# 4  2005  5  종로구   145     2   207

# %%
# 2019년 데이터만 추출하기
traffic_seoul_2019 = traffic_seoul[traffic_seoul.년도 == 2019]
traffic_seoul_2019.head()
# Out:
#         년도  월 자치구명  발생건수  사망자수  부상자수
# 4200  2019  1  종로구    87     1   125
# 4201  2019  2  종로구    66     1    84
# 4202  2019  3  종로구    87     2   122
# 4203  2019  4  종로구    85     0   131
# 4204  2019  5  종로구   112     1   158

# %%
# index 정리하기
traffic_seoul_2019.reset_index(inplace=True, drop=True)
traffic_seoul_2019.head()
# Out:
#      년도  월 자치구명  발생건수  사망자수  부상자수
# 0  2019  1  종로구    87     1   125
# 1  2019  2  종로구    66     1    84
# 2  2019  3  종로구    87     2   122
# 3  2019  4  종로구    85     0   131
# 4  2019  5  종로구   112     1   158

# %%
# 자치구별 발생건수, 사망자수, 부상자수 집계하기
traffic_analysis = traffic_seoul_2019.pivot_table(["발생건수", "부상자수", "사망자수"], 
                                                  aggfunc=sum, index="자치구명")
# pd.pivot_table(traffic_seoul_2019[["자치구명","발생건수", "부상자수", "사망자수"]], index="자치구명", aggfunc=sum)
traffic_analysis.head()
# Out:
#       발생건수  부상자수  사망자수
# 자치구명
# 강남구   3722  5182    14
# 강동구   1414  1910    11
# 강북구   1277  1706     7
# 강서구   1829  2491    20
# 관악구   1363  1755    10

# %%
# 위도, 경도 데이터 불러오기
seoul_limit = pd.read_csv("../Data/seoul.csv", encoding="euc-kr")
seoul_limit.columns = ["자치구명", "lon", "lat"]
seoul_limit.head()
# Out:
#   자치구명       lon       lat
# 0  강남구  127.0475  37.51731
# 1  강동구  127.1238  37.53013
# 2  강북구  127.0255  37.63975
# 3  관악구  126.9515  37.47834
# 4  구로구  126.8875  37.49547

# %%
# traffic_analysis와 seoul_limit 병합하기
data_result = pd.merge(left=traffic_analysis, right=seoul_limit, on="자치구명")
data_result.head()
# Out:
#   자치구명  발생건수  부상자수  사망자수       lon       lat
# 0  강남구  3722  5182    14  127.0475  37.51731
# 1  강동구  1414  1910    11  127.1238  37.53013
# 2  강북구  1277  1706     7  127.0255  37.63975
# 3  강서구  1829  2491    20  126.8496  37.55094
# 4  관악구  1363  1755    10  126.9515  37.47834

# %%
import folium

# %%
# folium은 int를 모르기 때문에 타입을 float로 바꿔줘야 한다.
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    25 non-null     object
#  1   발생건수    25 non-null     int64
#  2   부상자수    25 non-null     int64
#  3   사망자수    25 non-null     int64
#  4   lon     25 non-null     float64
#  5   lat     25 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
data_result[["발생건수", "부상자수", "사망자수"]] = data_result[["발생건수", "부상자수", "사망자수"]].astype("float64")

# %%
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    25 non-null     object
#  1   발생건수    25 non-null     float64
#  2   부상자수    25 non-null     float64
#  3   사망자수    25 non-null     float64
#  4   lon     25 non-null     float64
#  5   lat     25 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# ### 자치구의 구청을 표시하기

# %%
map = folium.Map(
                  location=[37.5502, 126.982],
                  zoom_start=11
)
for name, lat, lng in zip(data_result.자치구명, data_result.lat, data_result.lon):
  folium.Marker([lat, lng], popup=name).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9695def83fc8938290eb8e9082b6f5f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9695def83fc8938290eb8e9082b6f5f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9695def83fc8938290eb8e9082b6f5f2 = L.map(
#                 &quot;map_9695def83fc8938290eb8e9082b6f5f2&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3b3ecadb18932b998f9c5d592ed4739 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9695def83fc8938290eb8e9082b6f5f2);
#
#
#             var marker_8e3d1c553deae446cc4f14b345c05322 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_9695def83fc8938290eb8e9082b6f5f2);
#
#
#         var popup_4c66a9f1e3d535dd3b31848a4e1f507c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f02dea570fc586d4992ef5a9c44327cf = $(`&lt;div id=&quot;html_f02dea570fc586d4992ef5a9c44327cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_4c66a9f1e3d535dd3b31848a4e1f507c.setContent(html_f02dea570fc586d4992ef5a9c44327cf);
#
#
#         marker_8e3d1c553deae446cc4f14b345c05322.bindPopup(popup_4c66a9f1e3d535dd3b31848a4e1f507c)
#         ;
#
#
#
#
#             var marker_25d4648dd37e280a29e589e5a6df22bf = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_9695def83fc8938290eb8e9082b6f5f2);
#
#
#         var popup_29665297b7d653f33944a94fdc8d396a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_74bdadf621722183a7fe99e21b78f801 = $(`&lt;div id=&quot;html_74bdadf621722183a7fe99e21b78f801&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_29665297b7d653f33944a94fdc8d396a.setContent(html_74bdadf621722183a7fe99e21b78f801);
#
#
#         marker_25d4648dd37e280a29e589e5a6df22bf.bindPopup(popup_29665297b7d653f33944a94fdc8d396a)
#         ;
#
#
#
#
#             var marker_4f20797e24feda8b2be0e721512f5a0a = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_9695def83fc8938290eb8e9082b6f5f2);
#
#
#         var popup_7ee7b3cee650e62494144392dcccb13a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6b7ec446bcaf40cb10fb303241506b88 = $(`&lt;div id=&quot;html_6b7ec446bcaf40cb10fb303241506b88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북구&lt;/div&gt;`)[0];
#             popup_7ee7b3cee650e62494144392dcccb13a.setContent(html_6b7ec446bcaf40cb10fb303241506b88);
#
#
#         marker_4f20797e24feda8b2be0e721512f5a0a.bindPopup(popup_7ee7b3cee650e62494144392dcccb13a)
#         ;
#
#
#
#
#             var marker_38c191292f8ab37407bd13e0decc170c = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_9695def83fc8938290eb8e9082b6f5f2);
#
#
#         var popup_599b1e20df081407232c3bb5ec846323 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d34b75bb370f198e2e7362657c127418 = $(`&lt;div id=&quot;html_d34b75bb370f198e2e7362657c127418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강서구&lt;/div&gt;`)[0];
#             popup_599b1e20df081407232c3bb5ec846323.setContent(html_d34b75bb370f198e2e7362657c127418);
#
#
#         marker_38c191292f8ab37407bd13e0decc170c.bindPopup(popup_599b1e20df081407232c3bb5ec846323)
#         ;
#
#
#
#
#             var marker_21a660dff31ff1ab096e9cc301ed4509 = L.marker(
#                 [37.47834, 126.9515],
#                 {}
#             ).addTo(map_9695def83fc8938290eb8e9082b6f5f2);
#
#
#         var popup_fa04d571477e525ed3c538aa24afbc55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4a50e051b147d45c8506a7f527bb040b = $(`&lt;div id=&quot;html_4a50e051b147d45c8506a7f527bb040b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;관악구&lt;/div&gt;`)[0];
#             popup_fa04d571477e525ed3c538aa24afbc55.setContent(html_4a50e051b147d45c8506a7f527bb040b);
#
#
#         marker_21a660dff31ff1ab096e9cc301ed4509.bindPopup(popup_fa04d571477e525ed3c538aa24afbc55)
#         ;
#
#
#
#
#             var marker_b4972b0b050dfadc7ac60350962f951b = L.marker(
#                 [37.53862, 127.0824],
#                 {}
#             ).addTo(map_9695def83fc8938290eb8e9082b6f5f2);
#
#
#         var popup_f774848e959bc279b408e5f399eee6c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_021a83e1f223b435d36ac19a18a07778 = $(`&lt;div id=&quot;html_021a83e1f223b435d36ac19a18a07778&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&

# %%
map = folium.Map(
                  location=[37.5502, 126.982],
                  zoom_start=11
)

# 자치구별 교통사고 발생건수를 표시하기
for name, lat, lng, rad in zip(data_result.자치구명, data_result.lat, data_result.lon, data_result.발생건수):
  folium.Marker([lat, lng], popup=name).add_to(map)
  folium.CircleMarker(
    [lat, lng],
    radius = rad / 100, # 원의 반지름
    # color = "skyblue",
    # fill = True,
    fill_color = "magenta",
    fill_opacity = (rad / data_result.발생건수.max()) * 0.7,
    popup=name
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_477a223cdd2da4db3c7572383af3af44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_477a223cdd2da4db3c7572383af3af44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_477a223cdd2da4db3c7572383af3af44 = L.map(
#                 &quot;map_477a223cdd2da4db3c7572383af3af44&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4828a5b7f7c69ed63b1c3b9de3ac2fcb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_477a223cdd2da4db3c7572383af3af44);
#
#
#             var marker_fcbfbbc639853526f279b710ce278436 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_477a223cdd2da4db3c7572383af3af44);
#
#
#         var popup_bd467ab87294bc99b425274f32e73cac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7924f185d8e98493ebcc3031f275a3f9 = $(`&lt;div id=&quot;html_7924f185d8e98493ebcc3031f275a3f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_bd467ab87294bc99b425274f32e73cac.setContent(html_7924f185d8e98493ebcc3031f275a3f9);
#
#
#         marker_fcbfbbc639853526f279b710ce278436.bindPopup(popup_bd467ab87294bc99b425274f32e73cac)
#         ;
#
#
#
#
#             var circle_marker_627413d473284f184f2833bdbed55678 = L.circleMarker(
#                 [37.51731, 127.0475],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 37.22, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_477a223cdd2da4db3c7572383af3af44);
#
#
#         var popup_4b275ff6783d6b79f8a4e269ea6126b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a28a7ebac102f74d20e9cb2ca27bb799 = $(`&lt;div id=&quot;html_a28a7ebac102f74d20e9cb2ca27bb799&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_4b275ff6783d6b79f8a4e269ea6126b1.setContent(html_a28a7ebac102f74d20e9cb2ca27bb799);
#
#
#         circle_marker_627413d473284f184f2833bdbed55678.bindPopup(popup_4b275ff6783d6b79f8a4e269ea6126b1)
#         ;
#
#
#
#
#             var marker_d333f9cb4522ede9f7ba5992bd2c419a = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_477a223cdd2da4db3c7572383af3af44);
#
#
#         var popup_189785923b18b5b6cc24b74cc5de5230 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2a6d726d6aadf8469933f8cd8fd3019c = $(`&lt;div id=&quot;html_2a6d726d6aadf8469933f8cd8fd3019c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_189785923b18b5b6cc24b74cc5de5230.setContent(html_2a6d726d6aadf8469933f8cd8fd3019c);
#
#
#         marker_d333f9cb4522ede9f7ba5992bd2c419a.bindPopup(popup_189785923b18b5b6cc24b74cc5de5230)
#         ;
#
#
#
#
#             var circle_marker_4763e37b7d1192c234e1bbf01b433772 = L.circleMarker(
#                 [37.53013, 127.1238],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.26593229446534117, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14.14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_477a223cdd2da4db3c7572383af3af44);
#
#
#         var popup_936e947561557262934ef8f3351c6c92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3dc0034c082a6acadbdaf28ec931e496 = $(`&lt;div id=&quot;html_3dc0034c082a6acadbdaf28ec931e496&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_936e947561557262934ef8f3351c6c92.setContent(html_3dc0034c082a6acadbdaf28ec931e496);
#
#
#         circle_marker_4763e37b7d1192c234e1bbf01b433772.bindPopup(popup_936e947561557262934ef8f3351c6c92)
#         ;
#
#
#
#
#             var marker_6490a44594760cdda5c3e29715a37e22 = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_477a223cdd2da4db3c7572383af3af44);
#
#
#         var popup_220572bb597e3db322985bc8e6df4f76 = L.popup({&quot;

# %%
# 자치구별 교통사고 사망건수 표시하기
map = folium.Map(
                  location=[37.5502, 126.982],
                  zoom_start=11
)

# 자치구별 교통사고 발생건수를 표시하기
for name, lat, lng, rad in zip(data_result.자치구명, data_result.lat, data_result.lon, data_result.사망자수):
  folium.Marker([lat, lng], popup=name).add_to(map)
#   if ((rad == data_result.사망자수.max()) | (rad == data_result.사망자수.min())):
#     folium.CircleMarker(
#       [lat, lng],
#       radius = rad * 1.9, # 원의 반지름
#       color = "red",
#       # fill = True,
#       fill_color = "darkred",
#       fill_opacity = 0.2,
#       popup=name
#       ).add_to(map)
folium.CircleMarker(
      [data_result.loc[data_result.사망자수 == data_result.사망자수.max(),"lat"],
       data_result.loc[data_result.사망자수 == data_result.사망자수.max(),"lon"]],
      radius = data_result.사망자수.max() * 1.9, # 원의 반지름
      color = "red",
      # fill = True,
      fill_color = "darkred",
      fill_opacity = 0.2,
      popup=name
      ).add_to(map)
folium.CircleMarker(
      [data_result.loc[data_result.사망자수 == data_result.사망자수.min(),"lat"], 
      data_result.loc[data_result.사망자수 == data_result.사망자수.min(),"lon"]],
      radius = data_result.사망자수.min() * 1.9, # 원의 반지름
      color = "red",
      # fill = True,
      fill_color = "darkred",
      fill_opacity = 0.2,
      popup=name
      ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46e0228f385b5962f65375984d79bd56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46e0228f385b5962f65375984d79bd56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_46e0228f385b5962f65375984d79bd56 = L.map(
#                 &quot;map_46e0228f385b5962f65375984d79bd56&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51298eae14c9e0ac101cb8bcb6e0a0b8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46e0228f385b5962f65375984d79bd56);
#
#
#             var marker_c8eb1e567f35eb02eccb6c9154aa06b1 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_46e0228f385b5962f65375984d79bd56);
#
#
#         var popup_574b65cee1563bffb7bedb87b94bb8d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_921a7bdb183d4c680d61fbf202909ccf = $(`&lt;div id=&quot;html_921a7bdb183d4c680d61fbf202909ccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_574b65cee1563bffb7bedb87b94bb8d1.setContent(html_921a7bdb183d4c680d61fbf202909ccf);
#
#
#         marker_c8eb1e567f35eb02eccb6c9154aa06b1.bindPopup(popup_574b65cee1563bffb7bedb87b94bb8d1)
#         ;
#
#
#
#
#             var marker_4994c6cde44791f4aeb0ac4ecdeb8599 = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_46e0228f385b5962f65375984d79bd56);
#
#
#         var popup_edde30b364334807b467f8c979962d19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_305eb65c6145ed3b1acdb15dc97b7ec5 = $(`&lt;div id=&quot;html_305eb65c6145ed3b1acdb15dc97b7ec5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_edde30b364334807b467f8c979962d19.setContent(html_305eb65c6145ed3b1acdb15dc97b7ec5);
#
#
#         marker_4994c6cde44791f4aeb0ac4ecdeb8599.bindPopup(popup_edde30b364334807b467f8c979962d19)
#         ;
#
#
#
#
#             var marker_41c30b4c886332fc47f53414126ca437 = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_46e0228f385b5962f65375984d79bd56);
#
#
#         var popup_db458d01c263e93d65385885a768005e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a329589614cd3eb9f64f183caf5c9a5c = $(`&lt;div id=&quot;html_a329589614cd3eb9f64f183caf5c9a5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북구&lt;/div&gt;`)[0];
#             popup_db458d01c263e93d65385885a768005e.setContent(html_a329589614cd3eb9f64f183caf5c9a5c);
#
#
#         marker_41c30b4c886332fc47f53414126ca437.bindPopup(popup_db458d01c263e93d65385885a768005e)
#         ;
#
#
#
#
#             var marker_5a5b731aef4b76a0ba427e3148053dc0 = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_46e0228f385b5962f65375984d79bd56);
#
#
#         var popup_253d502af39c9fb62db2811e598d5b2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4e3b33747e69972240943b654dca41b7 = $(`&lt;div id=&quot;html_4e3b33747e69972240943b654dca41b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강서구&lt;/div&gt;`)[0];
#             popup_253d502af39c9fb62db2811e598d5b2f.setContent(html_4e3b33747e69972240943b654dca41b7);
#
#
#         marker_5a5b731aef4b76a0ba427e3148053dc0.bindPopup(popup_253d502af39c9fb62db2811e598d5b2f)
#         ;
#
#
#
#
#             var marker_5dde305bb467931930fa49b9462c05d4 = L.marker(
#                 [37.47834, 126.9515],
#                 {}
#             ).addTo(map_46e0228f385b5962f65375984d79bd56);
#
#
#         var popup_5d46a7144719d4fb5c1f6c04ece32423 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e9d47a983aaa5f011bdd315112260a8b = $(`&lt;div id=&quot;html_e9d47a983aaa5f011bdd315112260a8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;관악구&lt;/div&gt;`)[0];
#             popup_5d46a7144719d4fb5c1f6c04ece32423.setContent(html_e9d47a983aaa5f011bdd315112260a8b);
#
#
#         marker_5dde305bb467931930fa49b9462c05d4.bindPopup(popup_5d46a7144719d4fb5c1f6c04ece32423)
#         ;
#
#
#
#
#             var marker_b0aef8e0e8415ad69938c86704390697 = L.marker(
#                 [37.53862, 127.0824],
#                 {}
#             ).addTo(map_46e0228f385b5962f65375984d79bd56);
#
#
#         var popup_6db665e19c12768b0bb6971838a2b690 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c029efb714cf02f6f107fb767a5ef8c5 = $(`&lt;div id=&quot;html_c029efb714cf02f6f107fb767a5ef8c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&
